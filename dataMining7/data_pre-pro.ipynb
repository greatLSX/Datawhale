# %% [markdown]
# # 本次任务对数据进行探索和分析
# ## 数据类型的分析
# ## 无关特征删除
# ## 缺失值处理

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 导入数据和查看数据的基本情况

# %%
pd.set_option('display.max_columns', None)
data = pd.read_csv('./data.csv', encoding='GBK')

# %%
display(data.shape)
data.head()
# Out:
# (4754, 90)
#    Unnamed: 0   custid                          trade_no bank_card_no  \
# 0           5  2791858  20180507115231274000000023057383          卡号1
# 1          10   534047  20180507121002192000000023073000          卡号1
# 2          12  2849787  20180507125159718000000023114911          卡号1
# 3          13  1809708  20180507121358683000000388283484          卡号1
# 4          14  2499829  20180507115448545000000388205844          卡号1
#
#    low_volume_percent  middle_volume_percent  \
# 0                0.01                   0.99
# 1                0.02                   0.94
# 2                0.04                   0.96
# 3                0.00                   0.96
# 4                0.01                   0.99
#
#    take_amount_in_later_12_month_highest  trans_amount_increase_rate_lately  \
# 0                                      0                               0.90
# 1                                   2000                               1.28
# ...

# %%
# 查看数据的情况
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4754 entries, 0 to 4753
# Data columns (total 90 columns):
# Unnamed: 0                                    4754 non-null int64
# custid                                        4754 non-null int64
# trade_no                                      4754 non-null object
# bank_card_no                                  4754 non-null object
# low_volume_percent                            4752 non-null float64
# middle_volume_percent                         4752 non-null float64
# take_amount_in_later_12_month_highest         4754 non-null int64
# trans_amount_increase_rate_lately             4751 non-null float64
# trans_activity_month                          4752 non-null float64
# trans_activity_day                            4752 non-null float64
# transd_mcc                                    4752 non-null float64
# trans_days_interval_filter                    4746 non-null float64
# ...

# %% [markdown]
# ### 对数据进行去重并分割X和Y

# %%
data['y'] = data['status']
data.drop('status', axis=1, inplace=True)

# %%
# 去重
data = data.drop_duplicates()
data.shape
# Out:
# (4754, 90)

# %%
# 经过类似X['cusid'].value_counts()的观测，决定删除['cusid', 'bank_card_no', trade_no]
# X = X.drop([''Unnamed: 0', 'cusid', 'bank_card_no', 'trade_no'], axis=1, inplace=True)
# X.shape

data.drop(['custid', 'trade_no', 'bank_card_no', 'Unnamed: 0'], axis=1, inplace=True)
data.shape
# Out:
# (4754, 86)

# %% [markdown]
# ### 对X数据中类型为object的数据进行分析

# %%
display(data.describe())

obj_cols = [i for i in data.columns if data[i].dtype=='object']
display(obj_cols)
# Out:
#        low_volume_percent  middle_volume_percent  \
# count         4752.000000            4752.000000
# mean             0.021806               0.901294
# std              0.041527               0.144856
# min              0.000000               0.000000
# 25%              0.010000               0.880000
# 50%              0.010000               0.960000
# 75%              0.020000               0.990000
# max              1.000000               1.000000
#
#        take_amount_in_later_12_month_highest  \
# count                            4754.000000
# mean                             1940.197728
# std                              3923.971494
# min                                 0.000000
# 25%                                 0.000000
# 50%                               500.000000
# 75%                              2000.000000
# max                             68000.000000
#
#        trans_amount_increase_rate_lately  trans_activity_month  \
# ...

# %%
data[obj_cols].head(10)
# Out:
#   reg_preference_for_trad source id_name latest_query_time loans_latest_time
# 0                    一线城市     xs      蒋红        2018-04-25        2018-04-19
# 1                    一线城市     xs     崔向朝        2018-05-03        2018-05-05
# 2                    一线城市     xs     王中云        2018-05-05        2018-05-01
# 3                    三线城市     xs     何洋洋        2018-05-05        2018-05-03
# 4                    一线城市     xs      赵洋        2018-04-15        2018-01-07
# 5                    三线城市     xs      刘成        2018-05-04        2018-05-03
# 6                    一线城市     xs     周雨浓        2018-05-06        2018-05-04
# 7                    一线城市     xs     NaN               NaN               NaN
# 8                    三线城市     xs     周琰龙        2018-04-13        2018-04-30
# 9                    一线城市     xs     马晓辉        2018-04-16        2017-12-13

# %%
display(data['reg_preference_for_trad'].value_counts())
display(data['source'].value_counts())
# Out:
# 一线城市    3403
# 三线城市    1064
# 境外       150
# 二线城市     131
# 其他城市       4
# Name: reg_preference_for_trad, dtype: int64
# xs    4754
# Name: source, dtype: int64

# %%
data.drop(['source', 'id_name'], axis=1, inplace=True)
data.shape
# Out:
# (4754, 84)

# %%
# 对城市进行数值化操作
map_dict = {'一线城市': 1, '二线城市':2, '三线城市': 3, '境外': 4, '其他城市': 5,}
data['reg_preference_for_trad'] = data['reg_preference_for_trad'].map(map_dict)
data['reg_preference_for_trad'].head()
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    3.0
# 4    1.0
# Name: reg_preference_for_trad, dtype: float64

# %%
# 将日期处理成datatime格式
data['发生时间1'] = pd.to_datetime(data['latest_query_time'],format='%Y-%m-%d')#format='%Y%m%d%H%M%S'
data['发生时间2'] = pd.to_datetime(data['loans_latest_time'],format='%Y-%m-%d')#format='%Y%m%d%H%M%S'

data['发生时间2'].head()
# Out:
# 0   2018-04-19
# 1   2018-05-05
# 2   2018-05-01
# 3   2018-05-03
# 4   2018-01-07
# Name: 发生时间2, dtype: datetime64[ns]

# %%
data['年份1'] = [i.year for i in data['发生时间1']]
data['月份1'] = [i.month for i in data['发生时间1']]

data['年份2'] = [i.year for i in data['发生时间2']]
data['月份2'] = [i.month for i in data['发生时间2']]

# %%
cols = ['年份1','月份1','年份2','月份2']
for col in cols:
    data = data.join(pd.get_dummies(data[col]),how='left', lsuffix='_left', rsuffix='_right')

# %%
cols = ['年份1','月份1','年份2','月份2','发生时间1','发生时间2','latest_query_time','loans_latest_time']
for col in cols:
    data.drop([col],axis = 1,inplace = True)

# %% [markdown]
# ### 使用随即森林填充填充缺失值

# %%
# 删除缺失列中小于10的数据的行数据
data_miss = pd.DataFrame(data.isnull().sum(), columns=['num_null'])
data_miss_col = data.columns[data_miss['num_null'] < 10]
data = data.dropna(subset=data_miss_col)

# %%
# # 使用随机森林填充余下的缺失值
# data_miss = pd.DataFrame(data.isnull().sum(), columns=['num_null'])
# data_miss_col = list(data.columns[data_miss['num_null'] > 10])
# data_miss_col = data.columns[data_miss['num_null'] < 10]

# %%
# for i in data_miss_col:
#     fc = RandomForestClassifier()
#     y_train = data[i][data[i].notnull()]
#     x_train = data[data[i].notnull()].drop([i], axis=1)
#     x_test = data[data[i].isnull()].drop([i], axis=1)
#     fc.fit(x_train, y_train)
#     y_pre = fc.predict(x_test)
#     data[data[i].isnull(),i]=y_pre

# %%
# i = 'loans_product_count'
# x_train = data[data[i].notnull()].drop([i], axis=1)
# x_test = data[data[i].isnull()].drop([i], axis=1)
# x_test

# %% [markdown]
# ### 使用中值进行填充

# %%
for i in data.keys():
    data[i].fillna(data[i].median(), inplace=True)
data.isnull().sum().sort_values(ascending=False)
# Out:
# D:\WorkingSoft\Anaconda\install\lib\site-packages\pandas\core\generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# D:\WorkingSoft\Anaconda\install\lib\site-packages\pandas\core\generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# D:\WorkingSoft\Anaconda\install\lib\site-packages\pandas\core\generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %% [markdown]
# ### 相关性分析

# %%
Y = data['y']
X = data.drop(['y'], axis=1)

# %%
# 互信息法
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.feature_selection import mutual_info_classif as MIC
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import cross_val_score
result = MIC(X,Y)
k = result.shape[0] - sum(result <= 0)
# Out:
# D:\WorkingSoft\Anaconda\install\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
X_fsmic = SelectKBest(MIC, k).fit_transform(X, Y)
cross_val_score(RFC(n_estimators=10,random_state=0),X_fsmic,Y,cv=5).mean()
# Out:
# 0.7791315196261852

# %%
X_fsmic.shape
# Out:
# (4745, 66)

# %% [markdown]
# ### 划分训练集和测试集

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_fsmic, Y, random_state=2018, test_size=0.3)

# %%
# 随机森林
from sklearn.ensemble import RandomForestClassifier
from sklearn.grid_search import GridSearchCV
from sklearn import cross_validation, metrics
# Out:
# D:\WorkingSoft\Anaconda\install\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# D:\WorkingSoft\Anaconda\install\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
rf0 = RandomForestClassifier(oob_score=True, random_state=10)
rf0.fit(x_train, y_train)
print(rf0.oob_score_)
y_predprob = rf0.predict_proba(x_test)[:,1]
print("AUC Score (Train): %f" % metrics.roc_auc_score(y_test, y_predprob))
# Out:
# 0.7548931044866004
# AUC Score (Train): 0.730225
# D:\WorkingSoft\Anaconda\install\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# D:\WorkingSoft\Anaconda\install\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])

# %%
param_test1 = {'n_estimators':[10,15,20, 25, 30, 35,40, 45, 50, 55, 60,70, 75, 80, 90,95, 100]}
gsearch1 = GridSearchCV(estimator = RandomForestClassifier(min_samples_split=100,
                                  min_samples_leaf=20,max_depth=8,max_features='sqrt' ,random_state=10), 
                       param_grid = param_test1, scoring='roc_auc',cv=5)

gsearch1.fit(x_train,y_train)
gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# ([mean: 0.76275, std: 0.01922, params: {'n_estimators': 10},
#   mean: 0.76859, std: 0.02585, params: {'n_estimators': 15},
#   mean: 0.77016, std: 0.02236, params: {'n_estimators': 20},
#   mean: 0.76973, std: 0.02360, params: {'n_estimators': 25},
#   mean: 0.77195, std: 0.02718, params: {'n_estimators': 30},
#   mean: 0.77336, std: 0.02646, params: {'n_estimators': 35},
#   mean: 0.77482, std: 0.02639, params: {'n_estimators': 40},
#   mean: 0.77544, std: 0.02680, params: {'n_estimators': 45},
#   mean: 0.77640, std: 0.02614, params: {'n_estimators': 50},
#   mean: 0.77678, std: 0.02682, params: {'n_estimators': 55},
#   mean: 0.77733, std: 0.02738, params: {'n_estimators': 60},
#   mean: 0.77781, std: 0.02560, params: {'n_estimators': 70},
#   mean: 0.77778, std: 0.02519, params: {'n_estimators': 75},
#   mean: 0.77702, std: 0.02565, params: {'n_estimators': 80},
#   mean: 0.77763, std: 0.02561, params: {'n_estimators': 90},
# ...

# %%
param_test2 = {'max_depth':list(range(3,14,2)), 'min_samples_split':list(range(50,201,20))}
gsearch2 = GridSearchCV(estimator = RandomForestClassifier(n_estimators= 60, 
                                  min_samples_leaf=20,max_features='sqrt' ,oob_score=True, random_state=10),
   param_grid = param_test2, scoring='roc_auc',iid=False, cv=5)
gsearch2.fit(x_train,y_train)
gsearch2.grid_scores_, gsearch2.best_params_, gsearch2.best_score_
# Out:
# ([mean: 0.76548, std: 0.03394, params: {'max_depth': 3, 'min_samples_split': 50},
#   mean: 0.76652, std: 0.03369, params: {'max_depth': 3, 'min_samples_split': 70},
#   mean: 0.76639, std: 0.03329, params: {'max_depth': 3, 'min_samples_split': 90},
#   mean: 0.76664, std: 0.03214, params: {'max_depth': 3, 'min_samples_split': 110},
#   mean: 0.76660, std: 0.03177, params: {'max_depth': 3, 'min_samples_split': 130},
#   mean: 0.76645, std: 0.03219, params: {'max_depth': 3, 'min_samples_split': 150},
#   mean: 0.76551, std: 0.03188, params: {'max_depth': 3, 'min_samples_split': 170},
#   mean: 0.76437, std: 0.03287, params: {'max_depth': 3, 'min_samples_split': 190},
#   mean: 0.77572, std: 0.02646, params: {'max_depth': 5, 'min_samples_split': 50},
#   mean: 0.77486, std: 0.02507, params: {'max_depth': 5, 'min_samples_split': 70},
#   mean: 0.77369, std: 0.02471, params: {'max_depth': 5, 'min_samples_split': 90},
# ...

# %%
rf1 = RandomForestClassifier(n_estimators= 70, max_depth=11, min_samples_split=70,
                                  min_samples_leaf=20,max_features='sqrt' ,oob_score=True, random_state=10)
rf1.fit(x_train,y_train)
print(rf1.oob_score_)
# Out:
# 0.7904245709123758

# %%
param_test3 = {'min_samples_split':list(range(50,90,4)), 'min_samples_leaf':list(range(10,60,10))}
gsearch3 = GridSearchCV(estimator = RandomForestClassifier(n_estimators= 70, max_depth=11,
                                  max_features='sqrt' ,oob_score=True, random_state=10),
   param_grid = param_test3, scoring='roc_auc',iid=False, cv=5)
gsearch3.fit(x_train,y_train)
gsearch3.grid_scores_, gsearch3.best_params_, gsearch3.best_score_
# Out:
# ([mean: 0.78006, std: 0.02645, params: {'min_samples_leaf': 10, 'min_samples_split': 50},
#   mean: 0.77711, std: 0.02599, params: {'min_samples_leaf': 10, 'min_samples_split': 54},
#   mean: 0.77971, std: 0.02487, params: {'min_samples_leaf': 10, 'min_samples_split': 58},
#   mean: 0.77567, std: 0.02557, params: {'min_samples_leaf': 10, 'min_samples_split': 62},
#   mean: 0.77734, std: 0.02534, params: {'min_samples_leaf': 10, 'min_samples_split': 66},
#   mean: 0.77838, std: 0.02732, params: {'min_samples_leaf': 10, 'min_samples_split': 70},
#   mean: 0.77801, std: 0.02482, params: {'min_samples_leaf': 10, 'min_samples_split': 74},
#   mean: 0.77909, std: 0.02536, params: {'min_samples_leaf': 10, 'min_samples_split': 78},
#   mean: 0.77720, std: 0.02382, params: {'min_samples_leaf': 10, 'min_samples_split': 82},
#   mean: 0.77620, std: 0.02596, params: {'min_samples_leaf': 10, 'min_samples_split': 86},
# ...

# %%
param_test4 = {'max_features':list(range(3,11,2))}
gsearch4 = GridSearchCV(estimator = RandomForestClassifier(n_estimators= 70, max_depth=11, min_samples_split=60,
                                  min_samples_leaf=10 ,oob_score=True, random_state=10),
   param_grid = param_test4, scoring='roc_auc',iid=False, cv=5)
gsearch4.fit(x_train,y_train)
gsearch4.grid_scores_, gsearch4.best_params_, gsearch4.best_score_
# Out:
# ([mean: 0.76553, std: 0.02860, params: {'max_features': 3},
#   mean: 0.77275, std: 0.02954, params: {'max_features': 5},
#   mean: 0.77460, std: 0.02736, params: {'max_features': 7},
#   mean: 0.77711, std: 0.02225, params: {'max_features': 9}],
#  {'max_features': 9},
#  0.777109726887688)

# %%
rf2 = RandomForestClassifier(n_estimators= 70, max_depth=11, min_samples_split=60,
                                  min_samples_leaf=10,max_features=9 ,oob_score=True, random_state=10)
rf2.fit(x_train,y_train)
print(rf2.oob_score_)
y_predprob = rf0.predict_proba(x_test)[:,1]
print("AUC Score (Train): %f" % metrics.roc_auc_score(y_test, y_predprob))
print(rf2.score(x_test,y_test))
# Out:
# 0.7970490816019271
# AUC Score (Train): 0.730225
# 0.7752808988764045

# %% [markdown]
# ## 随机森林挑选特征

# %%
x_train_RF = pd.DataFrame(x_train)
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators= 70, max_depth=11, min_samples_split=60,
                                  min_samples_leaf=10,max_features=9 ,oob_score=True, random_state=10)
forest.fit(x_train_RF, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=11, max_features=9, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=10, min_samples_split=60,
#             min_weight_fraction_leaf=0.0, n_estimators=70, n_jobs=1,
#             oob_score=True, random_state=10, verbose=0, warm_start=False)

# %%
importance = forest.feature_importances_
imp_result = np.argsort(importance)[::-1]

for i in range(x_train_RF.shape[1]):
    print("%2d. %-*s %f"%(i+1, 30, x_train_RF.columns[i], importance[imp_result[i]]))
# Out:
#  1. 0                              0.131863
#  2. 1                              0.120905
#  3. 2                              0.086285
#  4. 3                              0.067092
#  5. 4                              0.057392
#  6. 5                              0.032466
#  7. 6                              0.028237
#  8. 7                              0.026239
#  9. 8                              0.026015
# 10. 9                              0.021462
# 11. 10                             0.020490
# 12. 11                             0.019933
# 13. 12                             0.019264
# 14. 13                             0.019011
# 15. 14                             0.018834
# 16. 15                             0.018026
# 17. 16                             0.014478
# 18. 17                             0.013989
# 19. 18                             0.013775
# 20. 19                             0.013193
# 21. 20                             0.012827
# ...

# %%
x_test_RF = pd.DataFrame(x_test)
threshold = 0.01
data_index = list(x_train_RF.columns[ importance < threshold])
x_train_RF.drop(data_index,axis=1,inplace=True)
x_test_RF.drop(data_index,axis = 1,inplace = True)
assert x_train_RF.shape[1] == x_test_RF.shape[1]

# %%
from sklearn import ensemble
forest = RandomForestClassifier(n_estimators= 70, max_depth=11, min_samples_split=60,
                                  min_samples_leaf=10,max_features=9 ,oob_score=True, random_state=10)
model_random_forest_Classifier.fit(x_train_RF,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=1,
#             oob_score=False, random_state=2019, verbose=0,
#             warm_start=False)

# %%
model_random_forest_Classifier.score(x_test_RF,y_test)
# Out:
# 0.7689606741573034

# %% [markdown]
# ## IV值

# %%
import math
import numpy as np
from scipy import stats
from sklearn.utils.multiclass import type_of_target

def woe(X, y, event=1):  
    res_woe = []
    iv_dict = {}
    for feature in X.columns:
        x = X[feature].values
        # 1) 连续特征离散化
        if type_of_target(x) == 'continuous':
            x = discrete(x)
        # 2) 计算该特征的woe和iv
        # woe_dict, iv = woe_single_x(x, y, feature, event)
        woe_dict, iv = woe_single_x(x, y, feature, event)
        iv_dict[feature] = iv
        res_woe.append(woe_dict) 
        
    return iv_dict
        
def discrete(x):
    # 使用5等分离散化特征
    res = np.zeros(x.shape)
    for i in range(5):
        point1 = stats.scoreatpercentile(x, i * 20)
        point2 = stats.scoreatpercentile(x, (i + 1) * 20)
        x1 = x[np.where((x >= point1) & (x <= point2))]
        mask = np.in1d(x, x1)
        res[mask] = i + 1    # 将[i, i+1]块内的值标记成i+1
    return res

def woe_single_x(x, y, feature,event = 1):
    # event代表预测正例的标签
    event_total = sum(y == event)
    non_event_total = y.shape[-1] - event_total
    
    iv = 0
    woe_dict = {}
    for x1 in set(x):    # 遍历各个块
        y1 = y.reindex(np.where(x == x1)[0])
        event_count = sum(y1 == event)
        non_event_count = y1.shape[-1] - event_count
        rate_event = event_count / event_total    
        rate_non_event = non_event_count / non_event_total
        
        if rate_event == 0:
            rate_event = 0.0001
            # woei = -20
        elif rate_non_event == 0:
            rate_non_event = 0.0001
            # woei = 20
        woei = math.log(rate_event / rate_non_event)
        woe_dict[x1] = woei
        iv += (rate_event - rate_non_event) * woei
    return woe_dict, iv

# %%
x_train_IV = pd.DataFrame(x_train)
x_test_IV = pd.DataFrame(x_test)
iv_dict = woe(x_train_IV, y_train)
iv = sorted(iv_dict.items(), key = lambda x:x[1],reverse = True)
print(len(iv))
iv
# Out:
# D:\WorkingSoft\Anaconda\install\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# 66
# [(7, 2.6789568819677667),
#  (10, 2.554472720871231),
#  (25, 2.250540630152946),
#  (6, 2.139710419608203),
#  (49, 1.4800834111353218),
#  (21, 1.453996275914024),
#  (22, 1.305351692896343),
#  (8, 1.1226849901596738),
#  (24, 1.0605962545256795),
#  (34, 0.8377065580809132),
#  (50, 0.826388047479922),
#  (28, 0.5837092614256388),
#  (40, 0.5703025046192388),
#  (53, 0.49996368527114676),
#  (16, 0.4695854687663071),
#  (44, 0.45426917071601347),
#  (41, 0.43683780625728197),
#  (39, 0.3884254629382107),
#  (27, 0.3767797598457921),
# ...

# %%
useless = []
for feature in x_train_IV.columns:
    if feature in [t[1] for t in iv[30:]]:
        useless.append(feature)
        print(feature, iv_dict[feature])

# %%
x_train_IV.drop(useless, axis = 1, inplace = True)
x_test_IV.drop(useless, axis = 1, inplace = True)

# %%
forest = RandomForestClassifier(n_estimators= 70, max_depth=11, min_samples_split=60,
                                  min_samples_leaf=10,max_features=9 ,oob_score=True, random_state=10)
model_random_forest_Classifier.fit(x_train_IV,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=1,
#             oob_score=False, random_state=2019, verbose=0,
#             warm_start=False)

# %%
model_random_forest_Classifier.score(x_test_IV,y_test)
# Out:
# 0.7710674157303371
